# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.5.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.17.0)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.44)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Downloading optuna-4.5.0-py3-none-any.whl (400 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.9/400.9 kB 8.1 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.10.1 optuna-4.5.0

# %%
import optuna
import torch
from torch import nn
import numpy
from pyspark.sql import SparkSession
from pyspark.ml.functions import vector_to_array
from pyspark.sql.functions import  col, when
import numpy as np

# %%
device  = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
spark  = SparkSession.builder.appName('Onehot').getOrCreate()

# %%
df = spark.read.csv('/content/drive/MyDrive/Bigdata-Machine_learning /cleaned_data/part-00000-41f8a7f7-767e-4f2b-9ac9-b59ff9174cdb-c000.csv', header=True, inferSchema=True)

# %%
# không sử dụng dữ liệu hình ảnh
features = ['n_citi', 'bed', 'bath', 'sqft', 'price']
df = df.select(features)
df.show(5)
# Out:
# +------+---+----+----+------+
# |n_citi|bed|bath|sqft| price|
# +------+---+----+----+------+
# |    48|  3|   2| 713|228500|
# |   152|  3|   1| 800|273950|
# |    48|  3|   1|1082|350000|
# |    55|  4|   3|2547|385100|
# |    55|  4|   3|2769|415000|
# +------+---+----+----+------+
# only showing top 5 rows

# %%
train_df, test_df = df.randomSplit([0.7, 0.3], seed=42)

# %%
y = ['price']
y_train_df = train_df.select(y)
x_train_df = train_df.drop('price')
y_test_df = test_df.select(y)
x_test_df = test_df.drop('price')

# %%
# xây dựng mô hình
class MLP_Regression(nn.Module):
  def __init__(self, input_size, hidden_layers, activations_func, output_size):
      super().__init__()
      layers = []
      pre_dim = input_size
      for h in hidden_layers:
        layers.append(nn.Linear(pre_dim, h))
        layers.append(activations_func())
        pre_dim = h
      layers.append(nn.Linear(pre_dim, output_size))
      layers.append(nn.ReLU())
      self.model = nn.Sequential(*layers)

  def forward(self, x):
      return self.model(x)

# %%
from sklearn.model_selection import KFold
from torch.utils.data import TensorDataset, DataLoader

# Hàm huấn luyện và chọn siêu tham số
best_RMSE_global = None
best_params_global = None

def Objective(X, y, trial):
  global best_RMSE_global
  global best_params_global
  ############# Khai báo hyper parameter grid #############
  num_hidden_layers = trial.suggest_int('num_hidden_layers', 2, 10)
  num_neural_for_each_hidden_layer = [trial.suggest_int(f'num_of_l{i}', 32, 256, step= 32) for i in range(num_hidden_layers)]
  activations_func = trial.suggest_categorical('activation', ['ReLU', 'Sigmoid', 'Tanh'])
  batch_size = trial.suggest_categorical('batch_size', [32, 64, 128])
  lr = trial.suggest_float('lr', 1e-4, 1e-2, log=True)
  epochs = trial.suggest_int('epoch', 50, 200, step= 10)
  #########################################################
  activation = getattr(nn, activations_func)

  model = MLP_Regression(X.shape[1],num_neural_for_each_hidden_layer, activation, y.shape[1]).to(device)

  kf = KFold(n_splits=5, shuffle=True, random_state=42)

  rmse = []
  for train_index, val_index in kf.split(X):
    X_train, X_val = X.iloc[train_index], X.iloc[val_index]
    y_train, y_val = y.iloc[train_index], y.iloc[val_index]

    x_tran_t = torch.tensor(X_train.values, dtype=torch.float32).to(device)
    y_tran_t = torch.tensor(y_train.values, dtype=torch.float32).to(device)
    x_val_t = torch.tensor(X_val.values, dtype=torch.float32).to(device)
    y_val_t = torch.tensor(y_val.values, dtype=torch.float32).to(device)

    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    loss_fn = nn.MSELoss()

    train_dataset = TensorDataset(x_tran_t, y_tran_t)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

    for epoch in range(epochs):
      model.train()
      for x_batch, y_batch in train_loader:
        optimizer.zero_grad()
        y_pred = model(x_batch)
        loss = loss_fn(y_pred, y_batch)
        loss.backward()
        optimizer.step()

    model.eval()
    with torch.no_grad():
      y_pred = model(x_val_t)
      loss = loss_fn(y_pred, y_val_t)
      rmse.append(np.sqrt(loss.item()))

  if best_RMSE_global is None or np.mean(rmse) < best_RMSE_global:

    best_RMSE_global = np.mean(rmse)
    best_params_global = trial.params

    torch.save({
    "input_dim": X.shape[1],
    "hidden_dim": num_neural_for_each_hidden_layer,
    "output_dim": y.shape[1],
    "activation_func": activations_func,
    "model_state_dict": model.state_dict()
      }, "checkpoint.pth")

  return np.mean(rmse)

# %%
train = optuna.create_study(direction='minimize')
x_train_PD = x_train_df.toPandas()
y_train_PD = y_train_df.toPandas()
# x_test_np = x_test_df.toPandas()
# y_test_np = y_test_df.toPandas()
train.optimize(lambda trial: Objective(x_train_PD, y_train_PD, trial), n_trials = 50)
# Out:
# [I 2025-10-20 17:03:01,225] A new study created in memory with name: no-name-709516e5-48a5-43e2-94a3-3339d94b503f
# [I 2025-10-20 17:15:51,978] Trial 0 finished with value: 828831.0892946229 and parameters: {'num_hidden_layers': 10, 'num_of_l0': 224, 'num_of_l1': 224, 'num_of_l2': 96, 'num_of_l3': 224, 'num_of_l4': 224, 'num_of_l5': 32, 'num_of_l6': 256, 'num_of_l7': 160, 'num_of_l8': 32, 'num_of_l9': 32, 'activation': 'Tanh', 'batch_size': 64, 'lr': 0.00028783232672048787, 'epoch': 150}. Best is trial 0 with value: 828831.0892946229.
# [I 2025-10-20 17:20:17,985] Trial 1 finished with value: 327886.39392959065 and parameters: {'num_hidden_layers': 2, 'num_of_l0': 192, 'num_of_l1': 64, 'activation': 'ReLU', 'batch_size': 32, 'lr': 0.00028896607261141226, 'epoch': 130}. Best is trial 1 with value: 327886.39392959065.
# [I 2025-10-20 17:37:39,806] Trial 2 finished with value: 326387.3493089583 and parameters: {'num_hidden_layers': 10, 'num_of_l0': 160, 'num_of_l1': 192, 'num_of_l2': 32, 'num_of_l3': 96, 'num_of_l4': 32, 'num_of_l5': 224, 'num_of_l6': 64, 'num_of_l7': 32, 'num_of_l8': 224, 'num_of_l9': 128, 'activation': 'ReLU', 'batch_size': 32, 'lr': 0.009140307327044113, 'epoch': 160}. Best is trial 2 with value: 326387.3493089583.
# [I 2025-10-20 17:44:21,306] Trial 3 finished with value: 799192.8599720572 and parameters: {'num_hidden_layers': 2, 'num_of_l0': 256, 'num_of_l1': 32, 'activation': 'Tanh', 'batch_size': 32, 'lr': 0.008339358244264468, 'epoch': 190}. Best is trial 2 with value: 326387.3493089583.
# [I 2025-10-20 17:49:50,133] Trial 4 finished with value: 324944.7355572867 and parameters: {'num_hidden_layers': 5, 'num_of_l0': 64, 'num_of_l1': 224, 'num_of_l2': 256, 'num_of_l3': 160, 'num_of_l4': 160, 'activation': 'ReLU', 'batch_size': 128, 'lr': 0.0011065953522894903, 'epoch': 150}. Best is trial 4 with value: 324944.7355572867.
# [I 2025-10-20 18:01:12,624] Trial 5 finished with value: 828831.0892946229 and parameters: {'num_hidden_layers': 8, 'num_of_l0': 192, 'num_of_l1': 96, 'num_of_l2': 256, 'num_of_l3': 256, 'num_of_l4': 224, 'num_of_l5': 64, 'num_of_l6': 128, 'num_of_l7': 64, 'activation': 'Sigmoid', 'batch_size': 32, 'lr': 0.00717860809129236, 'epoch': 90}. Best is trial 4 with value: 324944.7355572867.
# [I 2025-10-20 18:07:08,566] Trial 6 finished with value: 818174.9787432934 and parameters: {'num_hidden_layers': 3, 'num_of_l0': 96, 'num_of_l1': 224, 'num_of_l2': 224, 'activation': 'Tanh', 'batch_size': 64, 'lr': 0.001032287993857807, 'epoch': 160}. Best is trial 4 with value: 324944.7355572867.
# [I 2025-10-20 18:21:41,309] Trial 7 finished with value: 325513.1904019326 and parameters: {'num_hidden_layers': 5, 'num_of_l0': 160, 'num_of_l1': 160, 'num_of_l2': 96, 'num_of_l3': 224, 'num_of_l4': 192, 'activation': 'ReLU', 'batch_size': 32, 'lr': 0.0002374812335887191, 'epoch': 180}. Best is trial 4 with value: 324944.7355572867.
# [I 2025-10-20 18:31:12,329] Trial 8 finished with value: 328938.1745900437 and parameters: {'num_hidden_layers': 10, 'num_of_l0': 224, 'num_of_l1': 32, 'num_of_l2': 128, 'num_of_l3': 192, 'num_of_l4': 128, 'num_of_l5': 224, 'num_of_l6': 32, 'num_of_l7': 96, 'num_of_l8': 96, 'num_of_l9': 64, 'activation': 'ReLU', 'batch_size': 32, 'lr': 0.00010178066940933483, 'epoch': 90}. Best is trial 4 with value: 324944.7355572867.
# [I 2025-10-20 18:35:50,376] Trial 9 finished with value: 828831.0892946229 and parameters: {'num_hidden_layers': 9, 'num_of_l0': 192, 'num_of_l1': 160, 'num_of_l2': 96, 'num_of_l3': 64, 'num_of_l4': 160, 'num_of_l5': 32, 'num_of_l6': 224, 'num_of_l7': 192, 'num_of_l8': 224, 'activation': 'Sigmoid', 'batch_size': 128, 'lr': 0.005337050390943324, 'epoch': 100}. Best is trial 4 with value: 324944.7355572867.
# [I 2025-10-20 18:37:35,523] Trial 10 finished with value: 828831.0892946229 and parameters: {'num_hidden_layers': 6, 'num_of_l0': 32, 'num_of_l1': 256, 'num_of_l2': 192, 'num_of_l3': 128, 'num_of_l4': 96, 'num_of_l5': 128, 'activation': 'ReLU', 'batch_size': 128, 'lr': 0.0017181881298038628, 'epoch': 50}. Best is trial 4 with value: 324944.7355572867.
# [I 2025-10-20 18:43:15,631] Trial 11 finished with value: 325554.32443097985 and parameters: {'num_hidden_layers': 5, 'num_of_l0': 96, 'num_of_l1': 128, 'num_of_l2': 160, 'num_of_l3': 160, 'num_of_l4': 192, 'activation': 'ReLU', 'batch_size': 128, 'lr': 0.0004989884558677792, 'epoch': 190}. Best is trial 4 with value: 324944.7355572867.
# [I 2025-10-20 18:47:11,295] Trial 12 finished with value: 327598.28623775515 and parameters: {'num_hidden_layers': 4, 'num_of_l0': 96, 'num_of_l1': 160, 'num_of_l2': 64, 'num_of_l3': 192, 'activation': 'ReLU', 'batch_size': 128, 'lr': 0.0020070417873800338, 'epoch': 190}. Best is trial 4 with value: 324944.7355572867.
# [I 2025-10-20 18:53:33,846] Trial 13 finished with value: 328082.0303510138 and parameters: {'num_hidden_layers': 7, 'num_of_l0': 32, 'num_of_l1': 192, 'num_of_l2': 160, 'num_of_l3': 256, 'num_of_l4': 256, 'num_of_l5': 160, 'num_of_l6': 160, 'activation': 'ReLU', 'batch_size': 128, 'lr': 0.00010094342423870765, 'epoch': 140}. Best is trial 4 with value: 324944.7355572867.
# [I 2025-10-20 19:04:16,103] Trial 14 finished with value: 325840.858081136 and parameters: {'num_hidden_layers': 5, 'num_of_l0': 128, 'num_of_l1': 256, 'num_of_l2': 256, 'num_of_l3': 160, 'num_of_l4': 160, 'activation': 'ReLU', 'batch_size': 64, 'lr': 0.0005029659799914876, 'epoch': 170}. Best is trial 4 with value: 324944.7355572867.
# [I 2025-10-20 19:12:06,418] Trial 15 finished with value: 828831.0892946229 and parameters: {'num_hidden_layers': 6, 'num_of_l0': 64, 'num_of_l1': 128, 'num_of_l2': 128, 'num_of_l3': 32, 'num_of_l4': 96, 'num_of_l5': 256, 'activation': 'Sigmoid', 'batch_size': 32, 'lr': 0.00300521588031948, 'epoch': 110}. Best is trial 4 with value: 324944.7355572867.
# [I 2025-10-20 19:18:01,376] Trial 16 finished with value: 324231.55635939323 and parameters: {'num_hidden_layers': 4, 'num_of_l0': 128, 'num_of_l1': 192, 'num_of_l2': 192, 'num_of_l3': 192, 'activation': 'ReLU', 'batch_size': 128, 'lr': 0.0007381845331557239, 'epoch': 200}. Best is trial 16 with value: 324231.55635939323.
# [I 2025-10-20 19:23:36,317] Trial 17 finished with value: 326187.97797206556 and parameters: {'num_hidden_layers': 4, 'num_of_l0': 64, 'num_of_l1': 224, 'num_of_l2': 224, 'num_of_l3': 128, 'activation': 'ReLU', 'batch_size': 128, 'lr': 0.0008061232989226021, 'epoch': 200}. Best is trial 16 with value: 324231.55635939323.
# [I 2025-10-20 19:26:25,988] Trial 18 finished with value: 828831.0892946229 and parameters: {'num_hidden_layers': 3, 'num_of_l0': 128, 'num_of_l1': 192, 'num_of_l2': 192, 'activation': 'Sigmoid', 'batch_size': 128, 'lr': 0.0011747212542850276, 'epoch': 120}. Best is trial 16 with value: 324231.55635939323.
# [I 2025-10-20 19:28:48,611] Trial 19 finished with value: 828831.0892946229 and parameters: {'num_hidden_layers': 7, 'num_of_l0': 64, 'num_of_l1': 256, 'num_of_l2': 224, 'num_of_l3': 192, 'num_of_l4': 32, 'num_of_l5': 128, 'num_of_l6': 128, 'activation': 'Tanh', 'batch_size': 128, 'lr': 0.00301722376653757, 'epoch': 60}. Best is trial 16 with value: 324231.55635939323.
# [I 2025-10-20 19:32:34,612] Trial 20 finished with value: 326744.69027798035 and parameters: {'num_hidden_layers': 4, 'num_of_l0': 128, 'num_of_l1': 192, 'num_of_l2': 192, 'num_of_l3': 96, 'activation': 'ReLU', 'batch_size': 128, 'lr': 0.0005430652852972302, 'epoch': 140}. Best is trial 16 with value: 324231.55635939323.
# [I 2025-10-20 19:37:57,585] Trial 21 finished with value: 828831.0892946229 and parameters: {'num_hidden_layers': 5, 'num_of_l0': 160, 'num_of_l1': 160, 'num_of_l2': 96, 'num_of_l3': 224, 'num_of_l4': 192, 'activation': 'ReLU', 'batch_size': 128, 'lr': 0.0002019560908901535, 'epoch': 170}. Best is trial 16 with value: 324231.55635939323.
# [I 2025-10-20 19:57:13,985] Trial 22 finished with value: 828831.0892946229 and parameters: {'num_hidden_layers': 5, 'num_of_l0': 160, 'num_of_l1': 224, 'num_of_l2': 256, 'num_of_l3': 224, 'num_of_l4': 128, 'activation': 'ReLU', 'batch_size': 32, 'lr': 0.00020208894755963385, 'epoch': 180}. Best is trial 16 with value: 324231.55635939323.
# [I 2025-10-20 20:06:31,765] Trial 23 finished with value: 325381.5919697841 and parameters: {'num_hidden_layers': 6, 'num_of_l0': 96, 'num_of_l1': 128, 'num_of_l2': 64, 'num_of_l3': 160, 'num_of_l4': 192, 'num_of_l5': 96, 'activation': 'ReLU', 'batch_size': 64, 'lr': 0.000719388539598675, 'epoch': 200}. Best is trial 16 with value: 324231.55635939323.
# [I 2025-10-20 20:16:58,730] Trial 24 finished with value: 828831.0892946229 and parameters: {'num_hidden_layers': 7, 'num_of_l0': 96, 'num_of_l1': 96, 'num_of_l2': 32, 'num_of_l3': 160, 'num_of_l4': 256, 'num_of_l5': 96, 'num_of_l6': 192, 'activation': 'ReLU', 'batch_size': 64, 'lr': 0.0006956868430746381, 'epoch': 200}. Best is trial 16 with value: 324231.55635939323.
# [I 2025-10-20 20:22:17,465] Trial 25 finished with value: 324933.49074111856 and parameters: {'num_hidden_layers': 3, 'num_of_l0': 64, 'num_of_l1': 96, 'num_of_l2': 160, 'activation': 'ReLU', 'batch_size': 64, 'lr': 0.0014658732868564372, 'epoch': 200}. Best is trial 16 with value: 324231.55635939323.
# [I 2025-10-20 20:26:39,711] Trial 26 finished with value: 325438.85263024183 and parameters: {'num_hidden_layers': 3, 'num_of_l0': 32, 'num_of_l1': 96, 'num_of_l2': 160, 'activation': 'ReLU', 'batch_size': 64, 'lr': 0.001478842330385114, 'epoch': 170}. Best is trial 16 with value: 324231.55635939323.
# [I 2025-10-20 20:31:14,603] Trial 27 finished with value: 323859.9202837356 and parameters: {'num_hidden_layers': 3, 'num_of_l0': 64, 'num_of_l1': 64, 'num_of_l2': 192, 'activation': 'ReLU', 'batch_size': 64, 'lr': 0.002858747178606028, 'epoch': 180}. Best is trial 27 with value: 323859.9202837356.
# [I 2025-10-20 20:34:50,359] Trial 28 finished with value: 817810.4763274966 and parameters: {'num_hidden_layers': 2, 'num_of_l0': 64, 'num_of_l1': 64, 'activation': 'Sigmoid', 'batch_size': 64, 'lr': 0.0032840854145523603, 'epoch': 180}. Best is trial 27 with value: 323859.9202837356.
# [I 2025-10-20 20:39:49,561] Trial 29 finished with value: 803577.6388454275 and parameters: {'num_hidden_layers': 3, 'num_of_l0': 32, 'num_of_l1': 64, 'num_of_l2': 192, 'activation': 'Tanh', 'batch_size': 64, 'lr': 0.002291601455429925, 'epoch': 200}. Best is trial 27 with value: 323859.9202837356.
# [I 2025-10-20 20:44:47,190] Trial 30 finished with value: 821313.3386339925 and parameters: {'num_hidden_layers': 4, 'num_of_l0': 128, 'num_of_l1': 96, 'num_of_l2': 160, 'num_of_l3': 32, 'activation': 'Tanh', 'batch_size': 64, 'lr': 0.004963267404107536, 'epoch': 160}. Best is trial 27 with value: 323859.9202837356.
# [I 2025-10-20 20:48:59,505] Trial 31 finished with value: 828831.0892946229 and parameters: {'num_hidden_layers': 3, 'num_of_l0': 64, 'num_of_l1': 64, 'num_of_l2': 224, 'activation': 'ReLU', 'batch_size': 64, 'lr': 0.0013404770631382653, 'epoch': 150}. Best is trial 27 with value: 323859.9202837356.
# [I 2025-10-20 20:54:21,910] Trial 32 finished with value: 325871.3305073021 and parameters: {'num_hidden_layers': 4, 'num_of_l0': 64, 'num_of_l1': 32, 'num_of_l2': 192, 'num_of_l3': 96, 'activation': 'ReLU', 'batch_size': 64, 'lr': 0.00035523659343985784, 'epoch': 180}. Best is trial 27 with value: 323859.9202837356.
# [I 2025-10-20 20:57:24,578] Trial 33 finished with value: 828831.0892946229 and parameters: {'num_hidden_layers': 2, 'num_of_l0': 96, 'num_of_l1': 192, 'activation': 'ReLU', 'batch_size': 128, 'lr': 0.0009234793657657942, 'epoch': 190}. Best is trial 27 with value: 323859.9202837356.
# [I 2025-10-20 21:00:10,346] Trial 34 finished with value: 325785.42888267746 and parameters: {'num_hidden_layers': 2, 'num_of_l0': 32, 'num_of_l1': 224, 'activation': 'ReLU', 'batch_size': 64, 'lr': 0.002422429278250715, 'epoch': 140}. Best is trial 27 with value: 323859.9202837356.
# [I 2025-10-20 21:02:29,248] Trial 35 finished with value: 828831.0892946229 and parameters: {'num_hidden_layers': 3, 'num_of_l0': 64, 'num_of_l1': 64, 'num_of_l2': 128, 'activation': 'ReLU', 'batch_size': 128, 'lr': 0.0038911558748810403, 'epoch': 150}. Best is trial 27 with value: 323859.9202837356.
# [I 2025-10-20 21:09:15,840] Trial 36 finished with value: 333619.659101513 and parameters: {'num_hidden_layers': 4, 'num_of_l0': 224, 'num_of_l1': 96, 'num_of_l2': 224, 'num_of_l3': 128, 'activation': 'ReLU', 'batch_size': 64, 'lr': 0.001591920880463778, 'epoch': 170}. Best is trial 27 with value: 323859.9202837356.
# [I 2025-10-20 21:12:51,758] Trial 37 finished with value: 326658.20532855706 and parameters: {'num_hidden_layers': 2, 'num_of_l0': 96, 'num_of_l1': 32, 'activation': 'ReLU', 'batch_size': 64, 'lr': 0.0010157287195142826, 'epoch': 190}. Best is trial 27 with value: 323859.9202837356.
# [I 2025-10-20 21:16:17,287] Trial 38 finished with value: 827452.4851427812 and parameters: {'num_hidden_layers': 3, 'num_of_l0': 192, 'num_of_l1': 128, 'num_of_l2': 160, 'activation': 'Tanh', 'batch_size': 128, 'lr': 0.0003945247923036509, 'epoch': 150}. Best is trial 27 with value: 323859.9202837356.
# [I 2025-10-20 21:24:39,393] Trial 39 finished with value: 325096.4401683805 and parameters: {'num_hidden_layers': 4, 'num_of_l0': 128, 'num_of_l1': 192, 'num_of_l2': 256, 'num_of_l3': 192, 'activation': 'ReLU', 'batch_size': 64, 'lr': 0.006288937554681887, 'epoch': 160}. Best is trial 27 with value: 323859.9202837356.
# [I 2025-10-20 21:28:00,229] Trial 40 finished with value: 828831.0892946229 and parameters: {'num_hidden_layers': 6, 'num_of_l0': 32, 'num_of_l1': 64, 'num_of_l2': 192, 'num_of_l3': 64, 'num_of_l4': 96, 'num_of_l5': 192, 'activation': 'Sigmoid', 'batch_size': 128, 'lr': 0.0018537102358174603, 'epoch': 130}. Best is trial 27 with value: 323859.9202837356.
# [I 2025-10-20 21:36:14,908] Trial 41 finished with value: 323314.69269846287 and parameters: {'num_hidden_layers': 4, 'num_of_l0': 128, 'num_of_l1': 192, 'num_of_l2': 256, 'num_of_l3': 192, 'activation': 'ReLU', 'batch_size': 64, 'lr': 0.0068992358668713725, 'epoch': 160}. Best is trial 41 with value: 323314.69269846287.
# [I 2025-10-20 21:46:02,379] Trial 42 finished with value: 323342.6100790971 and parameters: {'num_hidden_layers': 5, 'num_of_l0': 160, 'num_of_l1': 224, 'num_of_l2': 256, 'num_of_l3': 192, 'num_of_l4': 64, 'activation': 'ReLU', 'batch_size': 64, 'lr': 0.004253585301071657, 'epoch': 160}. Best is trial 41 with value: 323314.69269846287.
# [I 2025-10-20 21:55:57,669] Trial 43 finished with value: 828831.0892946229 and parameters: {'num_hidden_layers': 4, 'num_of_l0': 160, 'num_of_l1': 224, 'num_of_l2': 256, 'num_of_l3': 192, 'activation': 'ReLU', 'batch_size': 64, 'lr': 0.009336409189942663, 'epoch': 190}. Best is trial 41 with value: 323314.69269846287.
# [I 2025-10-20 22:06:20,039] Trial 44 finished with value: 324605.01201334636 and parameters: {'num_hidden_layers': 5, 'num_of_l0': 256, 'num_of_l1': 160, 'num_of_l2': 224, 'num_of_l3': 224, 'num_of_l4': 64, 'activation': 'ReLU', 'batch_size': 64, 'lr': 0.004409886780130141, 'epoch': 180}. Best is trial 41 with value: 323314.69269846287.
# [I 2025-10-20 22:15:29,975] Trial 45 finished with value: 332182.1043453702 and parameters: {'num_hidden_layers': 5, 'num_of_l0': 256, 'num_of_l1': 160, 'num_of_l2': 224, 'num_of_l3': 224, 'num_of_l4': 64, 'activation': 'ReLU', 'batch_size': 64, 'lr': 0.004616960402113246, 'epoch': 160}. Best is trial 41 with value: 323314.69269846287.
# [W 2025-10-20 22:24:40,298] Trial 46 failed with parameters: {'num_hidden_layers': 5, 'num_of_l0': 224, 'num_of_l1': 192, 'num_of_l2': 256, 'num_of_l3': 256, 'num_of_l4': 64, 'activation': 'ReLU', 'batch_size': 64, 'lr': 0.00800167548276455, 'epoch': 180} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/optuna/study/_optimize.py", line 201, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipython-input-2216949919.py", line 6, in <lambda>
#     train.optimize(lambda trial: Objective(x_train_PD, y_train_PD, trial), n_trials = 50)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipython-input-755202622.py", line 48, in Objective
#     optimizer.step()
#   File "/usr/local/lib/python3.12/dist-packages/torch/optim/optimizer.py", line 516, in wrapper
#     out = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/optim/optimizer.py", line 81, in _use_grad
#     ret = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/optim/adam.py", line 247, in step
#     adam(
#   File "/usr/local/lib/python3.12/dist-packages/torch/optim/optimizer.py", line 149, in maybe_fallback
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/optim/adam.py", line 949, in adam
#     func(
#   File "/usr/local/lib/python3.12/dist-packages/torch/optim/adam.py", line 535, in _single_tensor_adam
#     param.addcdiv_(exp_avg, denom, value=-step_size)
# KeyboardInterrupt
# [W 2025-10-20 22:24:40,318] Trial 46 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2216949919.py in <cell line: 0>()
#       4 # x_test_np = x_test_df.toPandas()
#       5 # y_test_np = y_test_df.toPandas()
# ----> 6 train.optimize(lambda trial: Objective(x_train_PD, y_train_PD, trial), n_trials = 50)
#
# /usr/local/lib/python3.12/dist-packages/optuna/study/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     488                 If nested invocation of this method occurs.
#     489         """
# --> 490         _optimize(
#     491             study=self,
#     492             func=func,
#
# /usr/local/lib/python3.12/dist-packages/optuna/study/_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      61     try:
#      62         if n_jobs == 1:
# ---> 63             _optimize_sequential(
#      64                 study,
#      65                 func,
#
# /usr/local/lib/python3.12/dist-packages/optuna/study/_optimize.py in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     158
#     159         try:
# --> 160             frozen_trial_id = _run_trial(study, func, catch)
#     161         finally:
#     162             # The following line mitigates memory problems that can be occurred in some
#
# /usr/local/lib/python3.12/dist-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     256         and not isinstance(func_err, catch)
#     257     ):
# --> 258         raise func_err
#     259     return trial._trial_id
#     260
#
# /usr/local/lib/python3.12/dist-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     199     with get_heartbeat_thread(trial._trial_id, study._storage):
#     200         try:
# --> 201             value_or_values = func(trial)
#     202         except exceptions.TrialPruned as e:
#     203             # TODO(mamu): Handle multi-objective cases.
#
# /tmp/ipython-input-2216949919.py in <lambda>(trial)
#       4 # x_test_np = x_test_df.toPandas()
#       5 # y_test_np = y_test_df.toPandas()
# ----> 6 train.optimize(lambda trial: Objective(x_train_PD, y_train_PD, trial), n_trials = 50)
#
# /tmp/ipython-input-755202622.py in Objective(X, y, trial)
#      46         loss = loss_fn(y_pred, y_batch)
#      47         loss.backward()
# ---> 48         optimizer.step()
#      49
#      50     model.eval()
#
# /usr/local/lib/python3.12/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#     514                             )
#     515
# --> 516                 out = func(*args, **kwargs)
#     517                 self._optimizer_step_code()
#     518
#
# /usr/local/lib/python3.12/dist-packages/torch/optim/optimizer.py in _use_grad(*args, **kwargs)
#      79             torch.set_grad_enabled(self.defaults["differentiable"])
#      80             torch._dynamo.graph_break()
# ---> 81             ret = func(*args, **kwargs)
#      82         finally:
#      83             torch._dynamo.graph_break()
#
# /usr/local/lib/python3.12/dist-packages/torch/optim/adam.py in step(self, closure)
#     245             )
#     246
# --> 247             adam(
#     248                 params_with_grad,
#     249                 grads,
#
# /usr/local/lib/python3.12/dist-packages/torch/optim/optimizer.py in maybe_fallback(*args, **kwargs)
#     147                 return disabled_func(*args, **kwargs)
#     148             else:
# --> 149                 return func(*args, **kwargs)
#     150
#     151         return maybe_fallback
#
# /usr/local/lib/python3.12/dist-packages/torch/optim/adam.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, decoupled_weight_decay, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     947         func = _single_tensor_adam
#     948
# --> 949     func(
#     950         params,
#     951         grads,
#
# /usr/local/lib/python3.12/dist-packages/torch/optim/adam.py in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable, decoupled_weight_decay)
#     533                 denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
#     534
# --> 535             param.addcdiv_(exp_avg, denom, value=-step_size)
#     536
#     537         # Lastly, switch back to complex view
#
# KeyboardInterrupt:
